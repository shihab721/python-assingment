# %%
#List
students = ["Aman", "Riya", "Rakesh", "Priya", "Ankit","Neha", "Rohit", "Sneha", "Arjun", "Pooja"]
marks = [78, 92, 65, 88, 74, 95, 69, 81, 85, 90]
max_marks = max(marks)
min_marks = min(marks)
max_index = marks.index(max_marks)
min_index = marks.index(min_marks)
print("Student with Maximum Marks:")
print(students[max_index], "-", max_marks)
print("\nStudent with Minimum Marks:")
print(students[min_index], "-", min_marks)
# Out:
# Student with Maximum Marks:
# Neha - 95
#
# Student with Minimum Marks:
# Rakesh - 65

# %%
#Student marks
marks = []
for i in range(20):
    m = int(input("Enter marks of student " + str(i + 1) + ": "))
    marks.append(m)
# 1. Find average marks
average = sum(marks) / len(marks)
print("Average Marks =", average)
# 2. Find number of students scoring more than average
count = 0
for i in marks:
    if i > average:
        count += 1
print("Number of students scoring more than average =", count)
# 3. Find the marks scored by the maximum number of students (Mode)
max_count = 0
mode = marks[0]
for i in marks:
    c = marks.count(i)
    if c > max_count:
        max_count = c
        mode = i

print("Marks scored by maximum students =", mode)
# Out:
# Enter marks of student 1:  70
# Enter marks of student 2:  80
# Enter marks of student 3:  89
# Enter marks of student 4:  76
# Enter marks of student 5:  66
# Enter marks of student 6:  76
# Enter marks of student 7:  27
# Enter marks of student 8:  88
# Enter marks of student 9:  28
# Enter marks of student 10:  28
# Enter marks of student 11:  49
# Enter marks of student 12:  76
# Enter marks of student 13:  90
# Enter marks of student 14:  92
# Enter marks of student 15:  98
# Enter marks of student 16:  83
# Enter marks of student 17:  73
# Enter marks of student 18:  73
# Enter marks of student 19:  73
# Enter marks of student 20:  89
# Average Marks = 71.2
# Number of students scoring more than average = 14
# Marks scored by maximum students = 76
